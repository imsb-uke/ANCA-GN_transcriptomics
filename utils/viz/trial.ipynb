# %%
import matplotlib.pyplot as plt
import scanpy as sc

# %%
# jupyter lab fonts: pip install jupyterlab-fonts

# %%
filename = "../ANCA/ANCA_visium_raw/st_data_annots_v2.h5ad"

# %%
data = sc.read(filename)

# %%
data.obs.columns
# Out:
# Index(['in_tissue', 'array_row', 'array_col', 'sample', 'n_genes_by_counts',
#        'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts',
#        'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes',
#        'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes',
#        'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'n_genes',
#        'n_counts', 'cluster', 'annot_na', 'cluster_annot', 'annot_v1',
#        'count_v1', 'annot_v2', 'count_v2'],
#       dtype='object')

# %%
cluster_col = "cluster_annot"

# %%
from matplotlib import font_manager
av_fonts = [fontpath.split("/")[-1] for fontpath in font_manager.findSystemFonts(fontpaths=None, fontext='ttf')]

# %%
font_dirs = "./"
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

# %%
# custom_font_manager = matplotlib.font_manager.FontManager()
for font_file in font_files:
    font_manager.fontManager.addfont(font_file)

# %%
import matplotlib

# %%
matplotlib.pyplot.rcParams['font.family'] = "Roboto"
# matplotlib.pyplot.rcParams['font.weight'] = "regular"

matplotlib.pyplot.rcParams['figure.dpi'] = 100
matplotlib.pyplot.rcParams['figure.figsize'] = [5,5]

# %%
sc.pl.umap(data, color=cluster_col, frameon=False, s=20, title="Cluster annotation")
